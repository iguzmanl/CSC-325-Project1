# %%
import pandas as pd
import csv
import random

# %%
df = pd.read_csv("data_file.csv")
final_df = pd.read_csv("data_file.csv")

# %%
for index, row in final_df.iterrows():
    coin = random.randint(0,1) # 0 heads, 1 tails
    if coin == 1:
        coin = random.randint(0,1)
        for col in row:
            if coin == 0: # keep original value
                continue
            else:
                random_row = df.sample(n=1)
                row.at['User_Agent'] = random_row['User_Agent'].values[0] 
                random_row = df.sample(n=1)
                row.at['Page'] = random_row['Page'].values[0]
                random_row = df.sample(n=1)
                row.at['AcceptLanguage'] = random_row['AcceptLanguage'].values[0]
    else:
        continue

# %%
final_df.to_csv('final_df.csv')

df.describe()
# Out:
#                                                User_Agent AcceptLanguage  \
# count                                                2927           2927
# unique                                                 64            138
# top     Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.8...             si
# freq                                                  113             84
#
#        AcceptEncoding     Page
# count            2927     2927
# unique              1        6
# top              gzip  kitten3
# freq             2927      620

# %%
final_df.describe()
# Out:
#                                                User_Agent AcceptLanguage  \
# count                                                2927           2927
# unique                                                 64            138
# top     Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.8...             si
# freq                                                  116             84
#
#        AcceptEncoding     Page
# count            2927     2927
# unique              1        6
# top              gzip  kitten3
# freq             2927      616

# %%
df
# Out:
#                                              User_Agent AcceptLanguage  \
# 0     Mozilla/5.0 (X11; Linux x86_64; rv:38.0) Gecko...             ms
# 1     Mozilla/5.0 (X11; Linux x86_64; rv:38.0) Gecko...             ms
# 2     Mozilla/5.0 (X11; Linux x86_64; rv:38.0) Gecko...             ms
# 3     Mozilla/5.0 (X11; Linux x86_64; rv:38.0) Gecko...             ms
# 4     Mozilla/5.0 (X11; Linux x86_64; rv:38.0) Gecko...             ms
# 5     Mozilla/5.0 (X11; Linux x86_64; rv:38.0) Gecko...             ms
# 6     Mozilla/5.0 (X11; Linux x86_64; rv:38.0) Gecko...             ms
# 7     Mozilla/5.0 (X11; Linux x86_64; rv:38.0) Gecko...             ms
# 8     Mozilla/5.0 (Windows; U; Windows NT 6.0; en-US...             ss
# 9     Mozilla/5.0 (Windows; U; Windows NT 6.0; en-US...             ss
# 10    Mozilla/5.0 (Windows; U; Windows NT 6.0; en-US...             ss
# 11    Mozilla/5.0 (Windows; U; Windows NT 6.0; en-US...             ss
# ...

# %%
final_df
# Out:
#                                              User_Agent AcceptLanguage  \
# 0     Mozilla/5.0 (X11; Linux x86_64; rv:38.0) Gecko...             ms
# 1     Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US...             et
# 2     Mozilla/5.0 (X11; Linux x86_64; rv:38.0) Gecko...             ms
# 3     Mozilla/5.0 (X11; Linux x86_64; rv:38.0) Gecko...             ms
# 4     Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.8...             aa
# 5     Mozilla/5.0 (X11; Linux x86_64; rv:38.0) Gecko...             ms
# 6     Mozilla/5.0 (X11; Linux x86_64; rv:38.0) Gecko...             ms
# 7     Mozilla/5.0 (Windows; U; Windows NT 6.1; zh_CN...             av
# 8     Mozilla/5.0 (Windows; U; Windows NT 6.0; en-US...             ss
# 9     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...             tt
# 10    Mozilla/5.0 (Windows; U; Windows NT 6.0; en-US...             ss
# 11    Mozilla/5.0 (Windows; U; Windows NT 6.0; en-US...             ss
# ...

# %%
sub = final_df[~final_df.isin(df)]

# %%
sub.describe()
# Out:
#                                                User_Agent AcceptLanguage  \
# count                                                 725            726
# unique                                                 62            132
# top     Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.8...             si
# freq                                                   35             22
#
#         AcceptEncoding     Page
# count              0.0      595
# unique             0.0        6
# top                NaN  kitten3
# freq               NaN      123

# %%
sub
# Out:
#                                              User_Agent AcceptLanguage  \
# 0                                                   NaN            NaN
# 1     Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US...             et
# 2                                                   NaN            NaN
# 3                                                   NaN            NaN
# 4     Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.8...             aa
# 5                                                   NaN            NaN
# 6                                                   NaN            NaN
# 7     Mozilla/5.0 (Windows; U; Windows NT 6.1; zh_CN...             av
# 8                                                   NaN            NaN
# 9     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...             tt
# 10                                                  NaN            NaN
# 11                                                  NaN            NaN
# ...
